# %% [markdown]
# <a href="https://colab.research.google.com/github/Wiritpon-code/Project-University/blob/main/sport_watch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.read_csv('/content/drive/MyDrive/sport_watch.csv')
df.head()
# Out:
#    Duration  Average_Pulse  Max_Pulse  Calorie_Burnage  Hours_Work  \
# 0      30.0           85.0      120.0            250.0        10.0
# 1      45.0           90.0      130.0            260.0         8.0
# 2      45.0           95.0      130.0            270.0         8.0
# 3      45.0          100.0      140.0            280.0         0.0
# 4      60.0          105.0      140.0            290.0         7.0
#
#    Hours_Sleep
# 0          7.0
# 1          7.0
# 2          7.0
# 3          7.0
# 4          8.0

# %%
if 'slope_intercept_tempc' in locals() and len(slope_intercept_tempc) >= 2:
    slope_tempc = slope_intercept_tempc[0]
    intercept_tempc = slope_intercept_tempc[1]
    print(f"สมการเชิงเส้น: PM25_ugm3 = {slope_tempc:.2f} * TEMP_C + {intercept_tempc:.2f}")
else:
    print("ไม่พบค่าสัมประสิทธิ์สำหรับสมการเชิงเส้น PM25_ugm3 vs TEMP_C")

# %%
print(df)
# Out:
#    Duration  Average_Pulse  Max_Pulse  Calorie_Burnage  Hours_Work  \
# 0      30.0           85.0      120.0            250.0        10.0
# 1      45.0           90.0      130.0            260.0         8.0
# 2      45.0           95.0      130.0            270.0         8.0
# 3      45.0          100.0      140.0            280.0         0.0
# 4      60.0          105.0      140.0            290.0         7.0
# 5      60.0          110.0      145.0            300.0         7.0
# 6      60.0          115.0      145.0            310.0         8.0
# 7      75.0          120.0      150.0            320.0         0.0
# 8      75.0          125.0      150.0            330.0         8.0
# 9       NaN            NaN        NaN              NaN         NaN
#
#    Hours_Sleep
# 0          7.0
# 1          7.0
# 2          7.0
# 3          7.0
# 4          8.0
# 5          8.0
# 6          8.0
# 7          8.0
# 8          8.0
# 9          NaN

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Duration         9 non-null      float64
#  1   Average_Pulse    9 non-null      float64
#  2   Max_Pulse        9 non-null      float64
#  3   Calorie_Burnage  9 non-null      float64
#  4   Hours_Work       9 non-null      float64
#  5   Hours_Sleep      9 non-null      float64
# dtypes: float64(6)
# memory usage: 612.0 bytes
# None

# %%
df.describe()
# Out:
#        Duration  Average_Pulse   Max_Pulse  Calorie_Burnage  Hours_Work  \
# count       9.0       9.000000    9.000000         9.000000    9.000000
# mean       55.0     105.000000  138.888889       290.000000    6.222222
# std        15.0      13.693064   10.240171        27.386128    3.632416
# min        30.0      85.000000  120.000000       250.000000    0.000000
# 25%        45.0      95.000000  130.000000       270.000000    7.000000
# 50%        60.0     105.000000  140.000000       290.000000    8.000000
# 75%        60.0     115.000000  145.000000       310.000000    8.000000
# max        75.0     125.000000  150.000000       330.000000   10.000000
#
#        Hours_Sleep
# count     9.000000
# mean      7.555556
# std       0.527046
# min       7.000000
# 25%       7.000000
# 50%       8.000000
# 75%       8.000000
# max       8.000000

# %%
df.Hours_Sleep
# Out:
# 0    7.0
# 1    7.0
# 2    7.0
# 3    7.0
# 4    8.0
# 5    8.0
# 6    8.0
# 7    8.0
# 8    8.0
# 9    NaN
# Name: Hours_Sleep, dtype: float64

# %%
df_cleaned = df.dropna()
print(df_cleaned.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9 entries, 0 to 8
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Duration         9 non-null      float64
#  1   Average_Pulse    9 non-null      float64
#  2   Max_Pulse        9 non-null      float64
#  3   Calorie_Burnage  9 non-null      float64
#  4   Hours_Work       9 non-null      float64
#  5   Hours_Sleep      9 non-null      float64
# dtypes: float64(6)
# memory usage: 504.0 bytes
# None

# %%
print(df_cleaned)
# Out:
#    Duration  Average_Pulse  Max_Pulse  Calorie_Burnage  Hours_Work  \
# 0      30.0           85.0      120.0            250.0        10.0
# 1      45.0           90.0      130.0            260.0         8.0
# 2      45.0           95.0      130.0            270.0         8.0
# 3      45.0          100.0      140.0            280.0         0.0
# 4      60.0          105.0      140.0            290.0         7.0
# 5      60.0          110.0      145.0            300.0         7.0
# 6      60.0          115.0      145.0            310.0         8.0
# 7      75.0          120.0      150.0            320.0         0.0
# 8      75.0          125.0      150.0            330.0         8.0
#
#    Hours_Sleep
# 0          7.0
# 1          7.0
# 2          7.0
# 3          7.0
# 4          8.0
# 5          8.0
# 6          8.0
# 7          8.0
# 8          8.0

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 6))
sns.lineplot(x='Hours_Work', y='Hours_Sleep', data=df_cleaned)
plt.title('Line Graph of Hours_Work vs. Hours_Sleep')
plt.xlabel('Hours_Work (minutes)')
plt.ylabel('Hours_Sleep')
plt.grid(True)
plt.show()

# %%
display(df_cleaned.describe())
# Out:
#        Duration  Average_Pulse   Max_Pulse  Calorie_Burnage  Hours_Work  \
# count       9.0       9.000000    9.000000         9.000000    9.000000
# mean       55.0     105.000000  138.888889       290.000000    6.222222
# std        15.0      13.693064   10.240171        27.386128    3.632416
# min        30.0      85.000000  120.000000       250.000000    0.000000
# 25%        45.0      95.000000  130.000000       270.000000    7.000000
# 50%        60.0     105.000000  140.000000       290.000000    8.000000
# 75%        60.0     115.000000  145.000000       310.000000    8.000000
# max        75.0     125.000000  150.000000       330.000000   10.000000
#
#        Hours_Sleep
# count     9.000000
# mean      7.555556
# std       0.527046
# min       7.000000
# 25%       7.000000
# 50%       8.000000
# 75%       8.000000
# max       8.000000
